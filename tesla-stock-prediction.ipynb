# %%
###This is a program for prediction of stock movement and price prediction  by using the machine learning algorithm
###The stock prediction or the price prediction is one of the latest trends in financial market because investments can be make safer by algo trading .
###The machine learning algorithm that will be used is randomforestregressor and the datset si taken from kaggle 
#https://www.kaggle.com/datasets/ysthehurricane/tesla-stock-data-20162021

# %%
###importing all the necessary libraries

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
###collecting the data 


data=pd.read_csv("C:\DATASETS\TESLA_stock_prediction.csv")

data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2016-08-16   45.098000   45.438000   44.681999   44.722000   44.722000
# 1     2016-08-17   44.866001   44.966000   44.560001   44.647999   44.647999
# 2     2016-08-18   44.764000   45.132000   44.458000   44.702000   44.702000
# 3     2016-08-19   44.708000   45.034000   44.506001   45.000000   45.000000
# 4     2016-08-22   44.834000   45.021999   44.535999   44.585999   44.585999
# ...          ...         ...         ...         ...         ...         ...
# 1253  2021-08-09  710.169983  719.030029  705.130005  713.760010  713.760010
# 1254  2021-08-10  713.989990  716.590027  701.880005  709.989990  709.989990
# 1255  2021-08-11  712.710022  715.179993  704.210022  707.820007  707.820007
# 1256  2021-08-12  706.340027  722.799988  699.400024  722.250000  722.250000
# 1257  2021-08-13  723.710022  729.900024  714.340027  717.169983  717.169983
#
#         Volume
# 0     11335500
# ...

# %%
###the dataset we have is from the 2016-08-16 to 2021-08-13 


###data preprocessing and allocation of the data
data=data.drop(["Date"],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 5
#       1 ###the dataset we have is from the 2016-08-16 to 2021-08-13
#       2
#       3
#       4 ###data preprocessing and allocation of the data
# ----> 5 data=data.drop(["Date"],axis=1)
#       7 y=data["Adj Close"]
#       9 x=data.drop(["Adj Close"],axis=1)
#
# File c:\Users\pavan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
y=data["Adj Close"]

x=data.drop(["Adj Close"],axis=1)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train,x_test
# Out:
# (            Open        High         Low       Close     Volume
#  159    59.377998   60.962002   58.905998   60.740002   50673000
#  435    60.082001   61.402000   60.009998   61.369999   28637000
#  554    61.650002   67.980003   61.330002   66.180000  137127500
#  986   302.690002  307.502014  298.000000  300.167999   46650000
#  934   140.199997  152.399994  139.600006  152.238007   96185500
#  ...          ...         ...         ...         ...        ...
#  763    42.737999   43.450001   42.462002   43.118000   16127500
#  835    67.991997   70.146004   67.862000   69.767998   44141500
#  1216  597.539978  608.500000  593.500000  604.869995   22144100
#  559    68.748001   69.839996   68.181999   69.281998   39040000
#  684    51.360001   51.442001   49.020000   49.411999   50657000
#
#  [1006 rows x 5 columns],
#              Open        High         Low       Close     Volume
#  5      44.863998   45.698002   44.560001   44.967999   23922000
# ...

# %%
y_train,y_test
# Out:
# (159      60.740002
#  435      61.369999
#  554      66.180000
#  986     300.167999
#  934     152.238007
#             ...
#  763      43.118000
#  835      69.767998
#  1216    604.869995
#  559      69.281998
#  684      49.411999
#  Name: Adj Close, Length: 1006, dtype: float64,
#  5        44.967999
#  494      69.907997
#  52       39.993999
#  985     300.127991
#  186      64.961998
#             ...
#  1103    729.770020
#  31       40.139999
#  408      50.495998
#  64       36.754002
#  746      45.664001
#  Name: Adj Close, Length: 252, dtype: float64)

# %%
####model building and fitting to the model 



from sklearn.ensemble import RandomForestRegressor


mod1=RandomForestRegressor()


mod1.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
###model evaluation 






mod1.score(x_test,y_test)
# Out:
# 0.9998557651527137

# %%
###making predictions 

result1=mod1.predict(x_test)


plt.plot(result1,color="red",label="predicted")

# %%
fig,ax1=plt.subplots(1,1,figsize=(10,10))


ax1.bar(result1,y_test,color=("red","blue"))
ax1.plot(result1,y_test,color=("green"))
plt.xlabel("predicted vs Actual values")
# Out:
# Text(0.5, 0, 'predicted vs Actual values')

# %%
import pickle 

pickle.dump(mod1,open("model.pkl","wb"))
pickle.load(open("model.pkl","rb"))
# Out:
# RandomForestRegressor()
